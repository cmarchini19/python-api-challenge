# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st 

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Begin Establishing Dependencies
record_number = 1
set_number = 1
units = "Imperial"

#Make lists to store data from JSON into dataframe
cities_list = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []


#Print Data Retrieval for Cities

print("Beginning Data Retrieval")
print("------------------------")

for city_name in cities:
    if record_number > 50:
            set_number = set_number + 1
            record_number = 1
    weather_url = "http://api.openweathermap.org/data/2.5/weather?"+"&appid="+ weather_api_key + "&q=" + city_name + "&units=" + units
    print(f"Processing Record {record_number} of Set {set_number} | {city_name}")
    record_number = record_number + 1
    weather_json = requests.get(weather_url).json()
    if weather_json['cod']==200:
        cities_list.append(weather_json["name"])
        cloudiness.append(weather_json['clouds']['all'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
        humidity.append(weather_json['main']['humidity'])
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        max_temp.append(weather_json['main']['temp_max'])
        wind_speed.append(weather_json['wind']['speed'])
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | ilulissat
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | sinop
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | sao felix do xingu
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | mugumu
# Processing Record 8 of Set 1 | barentsburg
# Processing Record 9 of Set 1 | yuzhno-yeniseyskiy
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | birao
# Processing Record 13 of Set 1 | mackay
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | sibolga
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | lavrentiya
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | nouadhibou
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | samarai
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | padang
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | xuddur
# Processing Record 30 of Set 1 | nome
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | serra
# Processing Record 35 of Set 1 | salalah
# Processing Record 36 of Set 1 | canico
# Processing Record 37 of Set 1 | vila
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | belushya guba
# Processing Record 41 of Set 1 | taolanaro
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | vanimo
# Processing Record 44 of Set 1 | shihezi
# Processing Record 45 of Set 1 | dingle
# Processing Record 46 of Set 1 | bridgwater
# Processing Record 47 of Set 1 | ancud
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | vaitupu
# Processing Record 1 of Set 2 | chekhov
# Processing Record 2 of Set 2 | laguna
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | sao filipe
# Processing Record 5 of Set 2 | cozumel
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | labuhan
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | kamenka
# Processing Record 14 of Set 2 | narsaq
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | nuevo progreso
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | karkaralinsk
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | yarkovo
# Processing Record 22 of Set 2 | roald
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | jackson
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | fayaoue
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | atambua
# Processing Record 29 of Set 2 | burica
# Processing Record 30 of Set 2 | manta
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | batagay-alyta
# Processing Record 33 of Set 2 | sept-iles
# Processing Record 34 of Set 2 | itarema
# Processing Record 35 of Set 2 | clarence town
# Processing Record 36 of Set 2 | illoqqortoormiut
# Processing Record 37 of Set 2 | lubango
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | sorvag
# Processing Record 41 of Set 2 | jhelum
# Processing Record 42 of Set 2 | grindavik
# Processing Record 43 of Set 2 | bethel
# Processing Record 44 of Set 2 | bonavista
# Processing Record 45 of Set 2 | nouakchott
# Processing Record 46 of Set 2 | surt
# Processing Record 47 of Set 2 | plettenberg bay
# Processing Record 48 of Set 2 | krumovgrad
# Processing Record 49 of Set 2 | harper
# Processing Record 50 of Set 2 | katsiveli
# Processing Record 1 of Set 3 | erzin
# Processing Record 2 of Set 3 | dekar
# Processing Record 3 of Set 3 | disna
# Processing Record 4 of Set 3 | deputatskiy
# Processing Record 5 of Set 3 | bobo dioulasso
# Processing Record 6 of Set 3 | flin flon
# Processing Record 7 of Set 3 | ierapetra
# Processing Record 8 of Set 3 | jiazi
# Processing Record 9 of Set 3 | vestmannaeyjar
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | waipawa
# Processing Record 12 of Set 3 | chaohu
# Processing Record 13 of Set 3 | hilo
# Processing Record 14 of Set 3 | lucapa
# Processing Record 15 of Set 3 | konstantinovka
# Processing Record 16 of Set 3 | saint-joseph
# Processing Record 17 of Set 3 | ushtobe
# Processing Record 18 of Set 3 | nizhneyansk
# Processing Record 19 of Set 3 | toktogul
# Processing Record 20 of Set 3 | tarudant
# Processing Record 21 of Set 3 | caravelas
# Processing Record 22 of Set 3 | okhotsk
# Processing Record 23 of Set 3 | santander
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | yerbogachen
# Processing Record 26 of Set 3 | turka
# Processing Record 27 of Set 3 | pechora
# Processing Record 28 of Set 3 | gravelbourg
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | oussouye
# Processing Record 31 of Set 3 | srednekolymsk
# Processing Record 32 of Set 3 | tagusao
# Processing Record 33 of Set 3 | provideniya
# Processing Record 34 of Set 3 | pampa
# Processing Record 35 of Set 3 | puerto ayora
# Processing Record 36 of Set 3 | ruatoria
# Processing Record 37 of Set 3 | hvolsvollur
# Processing Record 38 of Set 3 | virginia beach
# Processing Record 39 of Set 3 | ostrovnoy
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | gizo
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | butaritari
# Processing Record 44 of Set 3 | manado
# Processing Record 45 of Set 3 | saint-georges
# Processing Record 46 of Set 3 | georgetown
# Processing Record 47 of Set 3 | dibaya
# Processing Record 48 of Set 3 | arraial do cabo
# Processing Record 49 of Set 3 | kamenskoye
# Processing Record 50 of Set 3 | santa rosa
# Processing Record 1 of Set 4 | inirida
# Processing Record 2 of Set 4 | cody
# Processing Record 3 of Set 4 | chernoyerkovskaya
# Processing Record 4 of Set 4 | kieta
# Processing Record 5 of Set 4 | saldanha
# Processing Record 6 of Set 4 | scottsbluff
# Processing Record 7 of Set 4 | lakatoro
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | acapulco
# Processing Record 10 of Set 4 | yar-sale
# Processing Record 11 of Set 4 | marsh harbour
# Processing Record 12 of Set 4 | makakilo city
# Processing Record 13 of Set 4 | saleilua
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | isangel
# Processing Record 16 of Set 4 | mandalgovi
# Processing Record 17 of Set 4 | general roca
# Processing Record 18 of Set 4 | grand river south east
# Processing Record 19 of Set 4 | ambovombe
# Processing Record 20 of Set 4 | namibe
# Processing Record 21 of Set 4 | rio grande
# Processing Record 22 of Set 4 | chifeng
# Processing Record 23 of Set 4 | tongzhou
# Processing Record 24 of Set 4 | watsa
# Processing Record 25 of Set 4 | gwadar
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | abiramam
# Processing Record 28 of Set 4 | homer
# Processing Record 29 of Set 4 | kaeo
# Processing Record 30 of Set 4 | caraballeda
# Processing Record 31 of Set 4 | ternate
# Processing Record 32 of Set 4 | berlevag
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | broken hill
# Processing Record 35 of Set 4 | horasan
# Processing Record 36 of Set 4 | sentyabrskiy
# Processing Record 37 of Set 4 | kendari
# Processing Record 38 of Set 4 | moose factory
# Processing Record 39 of Set 4 | chokurdakh
# Processing Record 40 of Set 4 | uruzgan
# Processing Record 41 of Set 4 | gualeguay
# Processing Record 42 of Set 4 | eyl
# Processing Record 43 of Set 4 | greenwood
# Processing Record 44 of Set 4 | afonso bezerra
# Processing Record 45 of Set 4 | tucuma
# Processing Record 46 of Set 4 | viligili
# Processing Record 47 of Set 4 | ketchikan
# Processing Record 48 of Set 4 | mananjary
# Processing Record 49 of Set 4 | egvekinot
# Processing Record 50 of Set 4 | sokoni
# Processing Record 1 of Set 5 | tumannyy
# Processing Record 2 of Set 5 | bandarbeyla
# Processing Record 3 of Set 5 | beyneu
# Processing Record 4 of Set 5 | warqla
# Processing Record 5 of Set 5 | qaanaaq
# Processing Record 6 of Set 5 | buenos aires
# Processing Record 7 of Set 5 | lagoa
# Processing Record 8 of Set 5 | havre-saint-pierre
# Processing Record 9 of Set 5 | puerto escondido
# Processing Record 10 of Set 5 | flinders
# Processing Record 11 of Set 5 | nantucket
# Processing Record 12 of Set 5 | dalvik
# Processing Record 13 of Set 5 | leningradskiy
# Processing Record 14 of Set 5 | nanortalik
# Processing Record 15 of Set 5 | alindao
# Processing Record 16 of Set 5 | japura
# Processing Record 17 of Set 5 | coahuayana
# Processing Record 18 of Set 5 | amderma
# Processing Record 19 of Set 5 | coihaique
# Processing Record 20 of Set 5 | saint-philippe
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | palabuhanratu
# Processing Record 23 of Set 5 | mundi
# Processing Record 24 of Set 5 | lata
# Processing Record 25 of Set 5 | veisiejai
# Processing Record 26 of Set 5 | kuhdasht
# Processing Record 27 of Set 5 | pandamatenga
# Processing Record 28 of Set 5 | severnoye
# Processing Record 29 of Set 5 | tessalit
# Processing Record 30 of Set 5 | ormara
# Processing Record 31 of Set 5 | brae
# Processing Record 32 of Set 5 | souillac
# Processing Record 33 of Set 5 | mys shmidta
# Processing Record 34 of Set 5 | half moon bay
# Processing Record 35 of Set 5 | esmeralda
# Processing Record 36 of Set 5 | orotukan
# Processing Record 37 of Set 5 | ola
# Processing Record 38 of Set 5 | farafenni
# Processing Record 39 of Set 5 | chilca
# Processing Record 40 of Set 5 | upernavik
# Processing Record 41 of Set 5 | kudahuvadhoo
# Processing Record 42 of Set 5 | cidahu
# Processing Record 43 of Set 5 | klaksvik
# Processing Record 44 of Set 5 | celestun
# Processing Record 45 of Set 5 | outjo
# Processing Record 46 of Set 5 | shingu
# Processing Record 47 of Set 5 | hofn
# Processing Record 48 of Set 5 | port blair
# Processing Record 49 of Set 5 | goderich
# Processing Record 50 of Set 5 | kirakira
# Processing Record 1 of Set 6 | asosa
# Processing Record 2 of Set 6 | aklavik
# Processing Record 3 of Set 6 | bathsheba
# Processing Record 4 of Set 6 | montanha
# Processing Record 5 of Set 6 | rocha
# Processing Record 6 of Set 6 | naze
# Processing Record 7 of Set 6 | phalaborwa
# Processing Record 8 of Set 6 | torbay
# Processing Record 9 of Set 6 | cocula
# Processing Record 10 of Set 6 | whyalla
# Processing Record 11 of Set 6 | sainte-savine
# Processing Record 12 of Set 6 | hamilton
# Processing Record 13 of Set 6 | berdigestyakh
# Processing Record 14 of Set 6 | hervey bay
# Processing Record 15 of Set 6 | cartagena
# Processing Record 16 of Set 6 | red bluff
# Processing Record 17 of Set 6 | sinnamary
# Processing Record 18 of Set 6 | chimoio
# Processing Record 19 of Set 6 | cabo san lucas
# Processing Record 20 of Set 6 | nishihara
# Processing Record 21 of Set 6 | chuy
# Processing Record 22 of Set 6 | marcona
# Processing Record 23 of Set 6 | antalaha
# Processing Record 24 of Set 6 | bambanglipuro
# Processing Record 25 of Set 6 | kruisfontein
# Processing Record 26 of Set 6 | qandala
# Processing Record 27 of Set 6 | lompoc
# Processing Record 28 of Set 6 | kropotkin
# Processing Record 29 of Set 6 | clyde river
# Processing Record 30 of Set 6 | touros
# Processing Record 31 of Set 6 | burgeo
# Processing Record 32 of Set 6 | jiayuguan
# Processing Record 33 of Set 6 | chapais
# Processing Record 34 of Set 6 | pocone
# Processing Record 35 of Set 6 | nyagan
# Processing Record 36 of Set 6 | sao domingos
# Processing Record 37 of Set 6 | kholodnyy
# Processing Record 38 of Set 6 | sur
# Processing Record 39 of Set 6 | vizinga
# Processing Record 40 of Set 6 | mayo
# Processing Record 41 of Set 6 | birjand
# Processing Record 42 of Set 6 | luderitz
# Processing Record 43 of Set 6 | westport
# Processing Record 44 of Set 6 | san ramon
# Processing Record 45 of Set 6 | talnakh
# Processing Record 46 of Set 6 | ettenheim
# Processing Record 47 of Set 6 | buraydah
# Processing Record 48 of Set 6 | marawi
# Processing Record 49 of Set 6 | ugoofaaru
# Processing Record 50 of Set 6 | pangody
# Processing Record 1 of Set 7 | airai
# Processing Record 2 of Set 7 | nim ka thana
# Processing Record 3 of Set 7 | anadyr
# Processing Record 4 of Set 7 | pevek
# Processing Record 5 of Set 7 | mumbwa
# Processing Record 6 of Set 7 | portales
# Processing Record 7 of Set 7 | bridgetown
# Processing Record 8 of Set 7 | port hedland
# Processing Record 9 of Set 7 | mount vernon
# Processing Record 10 of Set 7 | erenhot
# Processing Record 11 of Set 7 | ituni
# Processing Record 12 of Set 7 | smithers
# Processing Record 13 of Set 7 | neyshabur
# Processing Record 14 of Set 7 | puerto ayacucho
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | nhulunbuy
# Processing Record 17 of Set 7 | multai
# Processing Record 18 of Set 7 | port hardy
# Processing Record 19 of Set 7 | dezful
# Processing Record 20 of Set 7 | menongue
# Processing Record 21 of Set 7 | vao
# Processing Record 22 of Set 7 | fairbanks
# Processing Record 23 of Set 7 | praia
# Processing Record 24 of Set 7 | olafsvik
# Processing Record 25 of Set 7 | los llanos de aridane
# Processing Record 26 of Set 7 | dikson
# Processing Record 27 of Set 7 | vigia del fuerte
# Processing Record 28 of Set 7 | lushunkou
# Processing Record 29 of Set 7 | severo-kurilsk
# Processing Record 30 of Set 7 | kuruman
# Processing Record 31 of Set 7 | olinda
# Processing Record 32 of Set 7 | mount gambier
# Processing Record 33 of Set 7 | ariquemes
# Processing Record 34 of Set 7 | margate
# Processing Record 35 of Set 7 | maues
# Processing Record 36 of Set 7 | alofi
# Processing Record 37 of Set 7 | tabory
# Processing Record 38 of Set 7 | sarangani
# Processing Record 39 of Set 7 | boralday
# Processing Record 40 of Set 7 | sola
# Processing Record 41 of Set 7 | klichka
# Processing Record 42 of Set 7 | libertador general san martin
# Processing Record 43 of Set 7 | mahajanga
# Processing Record 44 of Set 7 | tashtyp
# Processing Record 45 of Set 7 | nivala
# Processing Record 46 of Set 7 | nezhinka
# Processing Record 47 of Set 7 | palmer
# Processing Record 48 of Set 7 | kholtoson
# Processing Record 49 of Set 7 | pacific grove
# Processing Record 50 of Set 7 | hanting
# Processing Record 1 of Set 8 | podbelsk
# Processing Record 2 of Set 8 | krasnousolskiy
# Processing Record 3 of Set 8 | tura
# Processing Record 4 of Set 8 | mentok
# Processing Record 5 of Set 8 | nicoya
# Processing Record 6 of Set 8 | jamame
# Processing Record 7 of Set 8 | riyadh
# Processing Record 8 of Set 8 | salinopolis
# Processing Record 9 of Set 8 | juneau
# Processing Record 10 of Set 8 | assens
# Processing Record 11 of Set 8 | yantal
# Processing Record 12 of Set 8 | dabola
# Processing Record 13 of Set 8 | port elizabeth
# Processing Record 14 of Set 8 | sobolevo
# Processing Record 15 of Set 8 | husavik
# Processing Record 16 of Set 8 | maceio
# Processing Record 17 of Set 8 | billings
# Processing Record 18 of Set 8 | maku
# Processing Record 19 of Set 8 | yumen
# Processing Record 20 of Set 8 | krasnoselkup
# Processing Record 21 of Set 8 | mehamn
# Processing Record 22 of Set 8 | aldergrove
# Processing Record 23 of Set 8 | manvi
# Processing Record 24 of Set 8 | yenagoa
# Processing Record 25 of Set 8 | comodoro rivadavia
# Processing Record 26 of Set 8 | bronnitsy
# Processing Record 27 of Set 8 | muli
# Processing Record 28 of Set 8 | podor
# Processing Record 29 of Set 8 | aykhal
# Processing Record 30 of Set 8 | mattru
# Processing Record 31 of Set 8 | karaul
# Processing Record 32 of Set 8 | panji
# Processing Record 33 of Set 8 | winnemucca
# Processing Record 34 of Set 8 | benguela
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | samusu
# Processing Record 37 of Set 8 | yaan
# Processing Record 38 of Set 8 | barda
# Processing Record 39 of Set 8 | ermelo
# Processing Record 40 of Set 8 | oriximina
# Processing Record 41 of Set 8 | dongsheng
# Processing Record 42 of Set 8 | dunedin
# Processing Record 43 of Set 8 | narasannapeta
# Processing Record 44 of Set 8 | shchelyayur
# Processing Record 45 of Set 8 | octeville
# Processing Record 46 of Set 8 | tazmalt
# Processing Record 47 of Set 8 | shahr-e babak
# Processing Record 48 of Set 8 | maniitsoq
# Processing Record 49 of Set 8 | tilichiki
# Processing Record 50 of Set 8 | saint-pierre
# Processing Record 1 of Set 9 | dryden
# Processing Record 2 of Set 9 | ulladulla
# Processing Record 3 of Set 9 | adrar
# Processing Record 4 of Set 9 | faanui
# Processing Record 5 of Set 9 | taizhou
# Processing Record 6 of Set 9 | okakarara
# Processing Record 7 of Set 9 | attawapiskat
# Processing Record 8 of Set 9 | yuzhne
# Processing Record 9 of Set 9 | kutoarjo
# Processing Record 10 of Set 9 | nylstroom
# Processing Record 11 of Set 9 | qui nhon
# Processing Record 12 of Set 9 | qunduz
# Processing Record 13 of Set 9 | camana
# Processing Record 14 of Set 9 | louisbourg
# Processing Record 15 of Set 9 | chebarkul
# Processing Record 16 of Set 9 | bakurianis andeziti
# Processing Record 17 of Set 9 | jumla
# Processing Record 18 of Set 9 | meulaboh
# Processing Record 19 of Set 9 | burlington
# Processing Record 20 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 9 | port macquarie
# Processing Record 22 of Set 9 | san vicente
# Processing Record 23 of Set 9 | barentu
# Processing Record 24 of Set 9 | katsuura
# Processing Record 25 of Set 9 | uspenka
# Processing Record 26 of Set 9 | ust-omchug
# Processing Record 27 of Set 9 | durant
# Processing Record 28 of Set 9 | skibbereen
# Processing Record 29 of Set 9 | enshi
# Processing Record 30 of Set 9 | necochea
# Processing Record 31 of Set 9 | sedhiou
# Processing Record 32 of Set 9 | geresk
# Processing Record 33 of Set 9 | grao mogol
# Processing Record 34 of Set 9 | vardo
# Processing Record 35 of Set 9 | lianran
# Processing Record 36 of Set 9 | norman wells
# Processing Record 37 of Set 9 | richards bay
# Processing Record 38 of Set 9 | rochegda
# Processing Record 39 of Set 9 | rawannawi
# Processing Record 40 of Set 9 | sao joao da barra
# Processing Record 41 of Set 9 | matagami
# Processing Record 42 of Set 9 | lixourion
# Processing Record 43 of Set 9 | nanakuli
# Processing Record 44 of Set 9 | neya
# Processing Record 45 of Set 9 | malyye derbety
# Processing Record 46 of Set 9 | butembo
# Processing Record 47 of Set 9 | anyang
# Processing Record 48 of Set 9 | zhigansk
# Processing Record 49 of Set 9 | morant bay
# Processing Record 50 of Set 9 | mount isa
# Processing Record 1 of Set 10 | saint-francois
# Processing Record 2 of Set 10 | tucuman
# Processing Record 3 of Set 10 | port keats
# Processing Record 4 of Set 10 | prescott
# Processing Record 5 of Set 10 | saravan
# Processing Record 6 of Set 10 | caluquembe
# Processing Record 7 of Set 10 | goalpara
# Processing Record 8 of Set 10 | tunduru
# Processing Record 9 of Set 10 | bayir
# Processing Record 10 of Set 10 | pizarro
# Processing Record 11 of Set 10 | storm lake
# Processing Record 12 of Set 10 | longyearbyen
# Processing Record 13 of Set 10 | youghal
# Processing Record 14 of Set 10 | saleaula
# Processing Record 15 of Set 10 | kashi
# Processing Record 16 of Set 10 | fort nelson
# Processing Record 17 of Set 10 | zeya
# Processing Record 18 of Set 10 | kizema
# Processing Record 19 of Set 10 | deming
# Processing Record 20 of Set 10 | geylegphug
# Processing Record 21 of Set 10 | poronaysk
# Processing Record 22 of Set 10 | mullaitivu
# Processing Record 23 of Set 10 | dunda
# Processing Record 24 of Set 10 | raton
# Processing Record 25 of Set 10 | zwedru
# Processing Record 26 of Set 10 | babanusah
# Processing Record 27 of Set 10 | narrabri
# Processing Record 28 of Set 10 | ajdabiya
# Processing Record 29 of Set 10 | sabibah
# Processing Record 30 of Set 10 | guerrero negro
# Processing Record 31 of Set 10 | sorong
# Processing Record 32 of Set 10 | galesong
# Processing Record 33 of Set 10 | krupanj
# Processing Record 34 of Set 10 | ndioum
# Processing Record 35 of Set 10 | sucua
# Processing Record 36 of Set 10 | mitchell
# Processing Record 37 of Set 10 | vuktyl
# Processing Record 38 of Set 10 | kangaatsiaq
# Processing Record 39 of Set 10 | deshna
# Processing Record 40 of Set 10 | pokhara
# Processing Record 41 of Set 10 | taoudenni
# Processing Record 42 of Set 10 | praya
# Processing Record 43 of Set 10 | romanovo
# Processing Record 44 of Set 10 | itacare
# Processing Record 45 of Set 10 | popondetta
# Processing Record 46 of Set 10 | shimoda
# Processing Record 47 of Set 10 | ust-tsilma
# Processing Record 48 of Set 10 | dawlatabad
# Processing Record 49 of Set 10 | kuala pilah
# Processing Record 50 of Set 10 | ajmer
# Processing Record 1 of Set 11 | fortuna
# Processing Record 2 of Set 11 | usinsk
# Processing Record 3 of Set 11 | ciudad guayana
# Processing Record 4 of Set 11 | zhengjiatun
# Processing Record 5 of Set 11 | tabou
# Processing Record 6 of Set 11 | natal
# Processing Record 7 of Set 11 | havoysund
# Processing Record 8 of Set 11 | york
# Processing Record 9 of Set 11 | marsassoum
# Processing Record 10 of Set 11 | mitzic
# Processing Record 11 of Set 11 | mago
# Processing Record 12 of Set 11 | shahrud
# Processing Record 13 of Set 11 | marang
# Processing Record 14 of Set 11 | conde
# Processing Record 15 of Set 11 | ahipara
# Processing Record 16 of Set 11 | temaraia
# Processing Record 17 of Set 11 | jacareacanga
# Processing Record 18 of Set 11 | new bern
# Processing Record 19 of Set 11 | turukhansk
# Processing Record 20 of Set 11 | qaqortoq
# Processing Record 21 of Set 11 | bilibino
# Processing Record 22 of Set 11 | lorengau
# Processing Record 23 of Set 11 | batu
# Processing Record 24 of Set 11 | gopalpur
# Processing Record 25 of Set 11 | ornskoldsvik
# Processing Record 26 of Set 11 | gangotri
# Processing Record 27 of Set 11 | blairmore
# Processing Record 28 of Set 11 | kaisiadorys
# Processing Record 29 of Set 11 | hambantota
# Processing Record 30 of Set 11 | kamaishi
# Processing Record 31 of Set 11 | ponta delgada
# Processing Record 32 of Set 11 | monte patria
# Processing Record 33 of Set 11 | barbastro
# Processing Record 34 of Set 11 | kannapolis
# Processing Record 35 of Set 11 | nioro
# Processing Record 36 of Set 11 | malindi
# Processing Record 37 of Set 11 | rolim de moura
# Processing Record 38 of Set 11 | constitucion
# Processing Record 39 of Set 11 | wamba
# Processing Record 40 of Set 11 | kalmunai
# Processing Record 41 of Set 11 | charters towers
# Processing Record 42 of Set 11 | edgewater
# Processing Record 43 of Set 11 | halifax
# Processing Record 44 of Set 11 | kintampo
# Processing Record 45 of Set 11 | afanasyevo
# Processing Record 46 of Set 11 | manoel urbano
# Processing Record 47 of Set 11 | biak
# Processing Record 48 of Set 11 | tuy hoa
# Processing Record 49 of Set 11 | bay roberts
# Processing Record 50 of Set 11 | cockburn town
# Processing Record 1 of Set 12 | oga
# Processing Record 2 of Set 12 | tawkar
# Processing Record 3 of Set 12 | mangan
# Processing Record 4 of Set 12 | hihifo
# Processing Record 5 of Set 12 | kungurtug
# Processing Record 6 of Set 12 | bassano
# Processing Record 7 of Set 12 | maningrida
# Processing Record 8 of Set 12 | mahanje
# Processing Record 9 of Set 12 | prince rupert
# Processing Record 10 of Set 12 | paraiso
# Processing Record 11 of Set 12 | linqiong
# Processing Record 12 of Set 12 | shiraz
# Processing Record 13 of Set 12 | blagoyevo
# Processing Record 14 of Set 12 | imola
# Processing Record 15 of Set 12 | tarakan
# Processing Record 16 of Set 12 | halalo
# Processing Record 17 of Set 12 | nurobod
# Processing Record 18 of Set 12 | de aar
# Processing Record 19 of Set 12 | griffith
# Processing Record 20 of Set 12 | rio cuarto
# Processing Record 21 of Set 12 | boatlaname
# Processing Record 22 of Set 12 | beloha
# Processing Record 23 of Set 12 | terra santa
# Processing Record 24 of Set 12 | te anau
# Processing Record 25 of Set 12 | labutta
# Processing Record 26 of Set 12 | dalby
# Processing Record 27 of Set 12 | pindi gheb
# Processing Record 28 of Set 12 | lodja
# Processing Record 29 of Set 12 | vryburg
# Processing Record 30 of Set 12 | herat
# Processing Record 31 of Set 12 | jarjis
# Processing Record 32 of Set 12 | taunggyi
# Processing Record 33 of Set 12 | taquari
# Processing Record 34 of Set 12 | perisor
# Processing Record 35 of Set 12 | rio gallegos
# Processing Record 36 of Set 12 | malwan
# Processing Record 37 of Set 12 | maragogi
# Processing Record 38 of Set 12 | northam
# Processing Record 39 of Set 12 | iracoubo
# Processing Record 40 of Set 12 | barabai
# Processing Record 41 of Set 12 | lolua
# Processing Record 42 of Set 12 | sarankhola
# Processing Record 43 of Set 12 | victor harbor
# Processing Record 44 of Set 12 | kansanshi
# Processing Record 45 of Set 12 | fernley
# Processing Record 46 of Set 12 | garden city
# Processing Record 47 of Set 12 | pereslavl-zalesskiy
# Processing Record 48 of Set 12 | batouri
# Processing Record 49 of Set 12 | chernyshevskiy
# Processing Record 50 of Set 12 | rincon
# Processing Record 1 of Set 13 | rudiskes
# Processing Record 2 of Set 13 | camacha
# Processing Record 3 of Set 13 | urubicha
# Processing Record 4 of Set 13 | bartica
# Processing Record 5 of Set 13 | praia da vitoria
# Processing Record 6 of Set 13 | hit
# Processing Record 7 of Set 13 | dar es salaam
# Processing Record 8 of Set 13 | sitka
# Processing Record 9 of Set 13 | baykit
# Processing Record 10 of Set 13 | taltal
# Processing Record 11 of Set 13 | churapcha
# Processing Record 12 of Set 13 | cayenne
# Processing Record 13 of Set 13 | tutoia
# Processing Record 14 of Set 13 | tuggurt
# Processing Record 15 of Set 13 | la palma
# Processing Record 16 of Set 13 | revelstoke
# Processing Record 17 of Set 13 | jatai

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Check the total count for each weather variable we are analyzing:
    # cities_list
    # cloudiness
    # country
    # date
    # humidity
    # lat
    # lng
    # max_temp 
    # wind_speed

print("Weather Variable Check")
print("----------------------")
print(f'City: {len(cities_list)}')
print(f'Cloudiness: {len(cloudiness)}')
print(f'Country: {len(country)}')
print(f'Date: {len(date)}')
print(f'Humidity: {len(humidity)}')
print(f'Lat: {len(lat)}')
print(f'Lng: {len(lng)}')
print(f'Max Temp: {len(max_temp)}')
print(f'Wind Speed: {len(wind_speed)}')
# Out:
# Weather Variable Check
# ----------------------
# City: 557
# Cloudiness: 557
# Country: 557
# Date: 557
# Humidity: 557
# Lat: 557
# Lng: 557
# Max Temp: 557
# Wind Speed: 557

# %%
#Establish Weather Dataframe
weather_df = pd.DataFrame({"Cities": cities_list, 
                           "Cloudiness": cloudiness,
                           "Country": country,
                           "Date": date,
                           "Humidity": humidity,
                           "Latitude": lat,
                           "Longitude": lng,
                           "Max Temp": max_temp,
                           "Wind Speed": wind_speed,
                          })
weather_df
# Out:
#                  Cities  Cloudiness Country        Date  Humidity  Latitude  \
# 0             Ilulissat          99      GL  1579928265        43     69.22
# 1                 Vaini          75      TO  1579928329        88    -21.20
# 2                 Sinop           0      TR  1579928329        56     41.77
# 3                Albany           1      US  1579928121        94     42.60
# 4    Sao Felix do Xingu         100      BR  1579928331        97     -6.64
# ..                  ...         ...     ...         ...       ...       ...
# 552             Cayenne          75      GF  1579928605        88      4.93
# 553              Tutoia          66      BR  1579928584        94     -2.76
# 554            La Palma          90      US  1579928606       100     33.85
# 555          Revelstoke          90      CA  1579928418       100     50.98
# 556               Jatai          88      BR  1579928607        98    -17.88
#
#      Longitude  Max Temp  Wind Speed
# 0       -51.10     12.20       20.80
# 1      -175.20     78.80        6.93
# 2        34.87     37.20        4.34
# 3       -73.97     37.40        4.70
# 4       -51.99     71.44        1.21
# ..         ...       ...         ...
# 552     -52.33     78.80        4.70
# 553     -42.27     75.72        3.47
# 554    -118.05     62.01        5.82
# 555    -118.20     33.80        5.82
# 556     -51.71     69.31        0.78
#
# [557 rows x 9 columns]

# %%
#Export city data into a CSV file
cities_weather_export = weather_df.to_csv('cities_weather.csv')
cities_weather_export

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create scatter plot showing latitude versus temperature
plt.scatter(lat, max_temp, marker="o", facecolors="cornflowerblue",edgecolors="black")

# Plot labels, gridlines, etc.
plt.title("City Latitude vs Max Temp (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("Lat_v_Temp_Plot.png")

# Show the scatterplot
plt.show()

# %%
# Latitude vs Max Temp - what's going on?
    # The code is showing the the relationship between each city's latitude and its max temperature (F).
    # What the plot shows here is the max temperature gets higher the closer to the equator you get.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create scatter plot showing latitude versus humidity
plt.scatter(lat, humidity, marker="o", facecolors="cornflowerblue",edgecolors="black")

# Plot labels, gridlines, etc.
plt.title("City Latitude vs Humidity (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("Lat_v_Hum_Plot.png")

# Show the scatterplot
plt.show()

# %%
# Latitude vs. Humidity Plot - what's going on?
    # The code is showing the the relationship between each city's latitude and its humidity %.
    # Something interesting the plot appears to show is a clustering of higher humidities between 60 and 80% for Latitudes between ~25 and 70.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create scatter plot showing latitude versus cloudiness
plt.scatter(lat, cloudiness, marker="o", facecolors="cornflowerblue",edgecolors="black")

# Plot labels, gridlines, etc.
plt.title("City Latitude vs Cloudiness (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("Lat_v_Cloud_Plot.png")

# Show the scatterplot
plt.show()

# %%
# Latitude vs. Cloudiness Plot - what's going on?
    # The plot is showing the relationship between a city's latitude and its cloudiness (%)
    # Interestingly, there appears to be a variety of clustering for various % cloudiness and latitudes. For example, cities between -40 lat and -20 lat and between 20 lat and 50 lat have 0% cloudiness.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create scatter plot showing latitude versus wind speed
plt.scatter(lat, wind_speed, marker="o", facecolors="cornflowerblue",edgecolors="black")

# Plot labels, gridlines, etc.
plt.title("City Latitude vs Wind Speed (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("Lat_v_Wind_Plot.png")

# Show the scatterplot
plt.show()

# %%
# Latitude vs. Wind Speed Plot - what's going on?
    # The plot is showing the relationship between a city's latitude and its wind speed (mph)
    # Cities between -40 and about 70 lat have wind speeds mostly betwwen 0 to 20 mph.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# Bin hemispheres
bins = [-200, 0, 200]
hemisphere = ["Southern Hemisphere", "Northern Hemisphere"]


# Add Hemisphere designation to weather dataframe
weather_df["Hemisphere"] = pd.cut(weather_df["Latitude"], bins, labels = hemisphere)
weather_df
# Out:
#                  Cities  Cloudiness Country        Date  Humidity  Latitude  \
# 0             Ilulissat          99      GL  1579928265        43     69.22
# 1                 Vaini          75      TO  1579928329        88    -21.20
# 2                 Sinop           0      TR  1579928329        56     41.77
# 3                Albany           1      US  1579928121        94     42.60
# 4    Sao Felix do Xingu         100      BR  1579928331        97     -6.64
# ..                  ...         ...     ...         ...       ...       ...
# 552             Cayenne          75      GF  1579928605        88      4.93
# 553              Tutoia          66      BR  1579928584        94     -2.76
# 554            La Palma          90      US  1579928606       100     33.85
# 555          Revelstoke          90      CA  1579928418       100     50.98
# 556               Jatai          88      BR  1579928607        98    -17.88
#
#      Longitude  Max Temp  Wind Speed           Hemisphere
# 0       -51.10     12.20       20.80  Northern Hemisphere
# 1      -175.20     78.80        6.93  Southern Hemisphere
# 2        34.87     37.20        4.34  Northern Hemisphere
# 3       -73.97     37.40        4.70  Northern Hemisphere
# 4       -51.99     71.44        1.21  Southern Hemisphere
# ..         ...       ...         ...                  ...
# 552     -52.33     78.80        4.70  Northern Hemisphere
# 553     -42.27     75.72        3.47  Southern Hemisphere
# 554    -118.05     62.01        5.82  Northern Hemisphere
# 555    -118.20     33.80        5.82  Northern Hemisphere
# 556     -51.71     69.31        0.78  Southern Hemisphere
#
# [557 rows x 10 columns]

# %%
# Make Northern Hemisphere Dataframe
nh_only = weather_df['Hemisphere']=='Northern Hemisphere'
nh_only

nh_df = weather_df[nh_only]
nh_df
# Out:
#            Cities  Cloudiness Country        Date  Humidity  Latitude  \
# 0       Ilulissat          99      GL  1579928265        43     69.22
# 2           Sinop           0      TR  1579928329        56     41.77
# 3          Albany           1      US  1579928121        94     42.60
# 7    Saint George           1      US  1579928127        59     37.10
# 9           Birao          18      CF  1579928334        20     10.28
# ..            ...         ...     ...         ...       ...       ...
# 549        Baykit          86      RU  1579928604        95     61.67
# 551     Churapcha          16      RU  1579928604        95     62.00
# 552       Cayenne          75      GF  1579928605        88      4.93
# 554      La Palma          90      US  1579928606       100     33.85
# 555    Revelstoke          90      CA  1579928418       100     50.98
#
#      Longitude  Max Temp  Wind Speed           Hemisphere
# 0       -51.10     12.20       20.80  Northern Hemisphere
# 2        34.87     37.20        4.34  Northern Hemisphere
# 3       -73.97     37.40        4.70  Northern Hemisphere
# 7      -113.58     46.99        0.34  Northern Hemisphere
# 9        22.79     56.50       17.31  Northern Hemisphere
# ..         ...       ...         ...                  ...
# 549      96.37     19.45        4.41  Northern Hemisphere
# 551     132.43    -35.70        4.07  Northern Hemisphere
# 552     -52.33     78.80        4.70  Northern Hemisphere
# 554    -118.05     62.01        5.82  Northern Hemisphere
# 555    -118.20     33.80        5.82  Northern Hemisphere
#
# [382 rows x 10 columns]

# %%
# Make Southern Hemisphere Dataframe
sh_only = weather_df['Hemisphere']=='Southern Hemisphere'
sh_only

sh_df = weather_df[sh_only]
sh_df
# Out:
#                  Cities  Cloudiness Country        Date  Humidity  Latitude  \
# 1                 Vaini          75      TO  1579928329        88    -21.20
# 4    Sao Felix do Xingu         100      BR  1579928331        97     -6.64
# 5             Carnarvon           0      AU  1579928331        48    -24.87
# 6                Mugumu          99      TZ  1579928332        71     -1.85
# 8            Bredasdorp          38      ZA  1579928267        94    -34.53
# ..                  ...         ...     ...         ...       ...       ...
# 543            Urubicha          54      BO  1579928599        56    -15.38
# 547       Dar es Salaam          75      TZ  1579928334        88     -6.82
# 550              Taltal           0      CL  1579928604        87    -25.40
# 553              Tutoia          66      BR  1579928584        94     -2.76
# 556               Jatai          88      BR  1579928607        98    -17.88
#
#      Longitude  Max Temp  Wind Speed           Hemisphere
# 1      -175.20     78.80        6.93  Southern Hemisphere
# 4       -51.99     71.44        1.21  Southern Hemisphere
# 5       113.63     87.80       19.46  Southern Hemisphere
# 6        34.70     70.95        3.65  Southern Hemisphere
# 8        20.04     68.00        2.82  Southern Hemisphere
# ..         ...       ...         ...                  ...
# 543     -62.95     75.78        1.01  Southern Hemisphere
# 547      39.27     80.60       11.41  Southern Hemisphere
# 550     -70.48     67.57        2.80  Southern Hemisphere
# 553     -42.27     75.72        3.47  Southern Hemisphere
# 556     -51.71     69.31        0.78  Southern Hemisphere
#
# [175 rows x 10 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build linear regression for Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = nh_df['Latitude']
y_values = nh_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatterplot linear regression for Northern Hemisphere - Max Temp vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (0,15), fontsize=15,color="red")
plt.title("NH: Max Temp vs Latitude Linear Regression (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Added in Pearson correlation
correlation = st.pearsonr(x_values, y_values)
print(f'The pearson correlation is: {round(correlation[0],2)}')

# Print r-squared value
print(f"The r-squared is: {rvalue}")

# Save the figure and show it
plt.savefig("NH_Temp_vs_Lat_LinReg.png")
plt.show()
# Out:
# The pearson correlation is: -0.87
# The r-squared is: -0.8740537449743527

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build linear regression for Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = sh_df['Latitude']
y_values = sh_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatterplot linear regression for Southern Hemisphere - Max Temp vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-40, 50), fontsize=15,color="red")
plt.title("SH: Max Temp vs Latitude Linear Regression (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Print pearson correlation
correlation = st.pearsonr(x_values, y_values)
print(f'The pearson correlation is: {round(correlation[0],2)}')

# Print r-squared value
print(f"The r-squared is: {rvalue}")

# Save the figure and show it
plt.savefig("SH_Temp_vs_Lat_LinReg.png")
plt.show()
# Out:
# The pearson correlation is: 0.5
# The r-squared is: 0.49671774398272917

# %%
# What's happening in the Max Temp vs Latitude linear regressions?
    # For the Northern Hemisphere, there is a strong negative relationship (r squared = -0.87) between the max temp and a city's latitude. The further from the equator, the max tempertature decreases.
    # For the Southern Hemisphere, there is a moderately postive relationship (r squared = 0.50) between the max temp and a city's latitude. The closer a city's latitude is to the equator, the higher its maximum temp.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build linear regression for Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = nh_df['Latitude']
y_values = nh_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatterplot linear regression for Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (30,20), fontsize=15,color="red")
plt.title("NH: Humidity (%) vs Latitude Linear Regression (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Print pearson correlation
correlation = st.pearsonr(x_values, y_values)
print(f'The pearson correlation is: {round(correlation[0],2)}')

# Print r-squared value
print(f"The r-squared is: {rvalue}")

# Save the figure and show it
plt.savefig("NH_Hum_vs_Lat_LinReg.png")
plt.show()
# Out:
# The pearson correlation is: 0.39
# The r-squared is: 0.39375436098048033

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build linear regression for Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = sh_df['Latitude']
y_values = sh_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatterplot linear regression for Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-30, 40), fontsize=15,color="red")
plt.title("SH: Humidity (%) vs Latitude Linear Regression (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Print pearson correlation
correlation = st.pearsonr(x_values, y_values)
print(f'The pearson correlation is: {round(correlation[0],2)}')

# Print r-squared value
print(f"The r-squared is: {rvalue}")

# Save the figure and show it
plt.savefig("SH_Hum_vs_Lat_LinReg.png")
plt.show()
# Out:
# The pearson correlation is: 0.23
# The r-squared is: 0.233707860385473

# %%
# What's happening in the Humidity % vs Latitude linear regressions?
    # For the Northern Hemisphere, there is a positive relationship (r squared = 0.39) between the humidity % and a city's latitude. Cities with latitudes moving away from the equator have increasing humidity %s.
    # For the Southern Hemisphere, there is a weaker postive relationship (r squared = 0.23) between the the humidity % and a city's latitude. Cities with latitudes moving toward the equator have increasing humidity %s, but this relationship is weaker than those cities in analyzed in the Northern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Build linear regression for Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = nh_df['Latitude']
y_values = nh_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatterplot linear regression for Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (20, 45), fontsize=15,color="red")
plt.title("NH: Cloudiness (%) vs Latitude Linear Regression (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


# Print pearson correlation
correlation = st.pearsonr(x_values, y_values)
print(f'The pearson correlation is: {round(correlation[0],2)}')

# Print r-squared value
print(f"The r-squared is: {rvalue}")

# Save the figure and show it
plt.savefig("NH_Cloud_vs_Lat_LinReg.png")
plt.show()
# Out:
# The pearson correlation is: 0.21
# The r-squared is: 0.21025747483801677

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Build linear regression for Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = sh_df['Latitude']
y_values = sh_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatterplot linear regression for Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-55,45), fontsize=15,color="red")
plt.title("SH: Cloudiness (%) vs Latitude Linear Regression (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Print pearson correlation
correlation = st.pearsonr(x_values, y_values)
print(f'The pearson correlation is: {round(correlation[0],2)}')

# Print r-squared value
print(f"The r-squared is: {rvalue}")

# Save the figure and show it
plt.savefig("SH_Cloud_vs_Lat_LinReg.png")
plt.show()
# Out:
# The pearson correlation is: 0.34
# The r-squared is: 0.34448703897686084

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Build linear regression for Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = nh_df['Latitude']
y_values = nh_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatterplot linear regression for Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (2, 20), fontsize=15,color="red")
plt.title("NH: Wind Speed (mph) vs Latitude Linear Regression (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Print pearson correlation
correlation = st.pearsonr(x_values, y_values)
print(f'The pearson correlation is: {round(correlation[0],2)}')

# Print r-squared value
print(f"The r-squared is: {rvalue}")

# Save the figure and show it
plt.savefig("NH_Wind_vs_Lat_LinReg.png")
plt.show()
# Out:
# The pearson correlation is: 0.17
# The r-squared is: 0.17309832031067232

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Build linear regression for Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = sh_df['Latitude']
y_values = sh_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatterplot linear regression for Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (-55,21), fontsize=15,color="red")
plt.title("SH: Wind Speed (mph) vs Latitude Linear Regression (1/24/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Print pearson correlation
correlation = st.pearsonr(x_values, y_values)
print(f'The pearson correlation is: {round(correlation[0],2)}')

# Print r-squared value
print(f"The r-squared is: {rvalue}")

# Save the figure and show it
plt.savefig("SH_Wind_vs_Lat_LinReg.png")
plt.show()
# Out:
# The pearson correlation is: -0.24
# The r-squared is: -0.23902501806758963
